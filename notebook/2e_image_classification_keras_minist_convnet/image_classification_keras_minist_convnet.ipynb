# %% [markdown]
# # Build a simple ML pipeline for image classification
#
# **Requirements** - In order to benefit from this tutorial, you will need:
# - A basic understanding of Machine Learning
# - An Azure account with an active subscription - [Create an account for free](https://azure.microsoft.com/free/?WT.mc_id=A261C142F)
# - An Azure ML workspace with computer cluster - [Configure workspace](../../configuration.ipynb)
# - A python environment
# - Installed Azure Machine Learning Python SDK v2 - [install instructions](../../../README.md) - check the getting started section
#
# **Learning Objectives** - By the end of this tutorial, you should be able to:
# - Connect to your AML workspace from the Python SDK
# - Create `Pipeline` with components
#
# **Motivations** -This tutorial shows how to train a simple deep neural network using the [Fashion MNIST dataset and Keras on Azure Machine Learning. Fashion-MNIST is a dataset of Zalando's article images-consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes.

# %% [markdown]
# # 1. Connect to Azure Machine Learning Workspace
#
# The [workspace](https://docs.microsoft.com/en-us/azure/machine-learning/concept-workspace) is the top-level resource for Azure Machine Learning, providing a centralized place to work with all the artifacts you create when you use Azure Machine Learning. In this section we will connect to the workspace in which the job will be run.
#
# ## 1.1 Import the required libraries

# %%
# import required libraries
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential

from azure.ai.ml import MLClient
from azure.ai.ml.dsl import pipeline
from azure.ai.ml import load_component

# %% [markdown]
# ## 1.2 Configure credential
# We are using `DefaultAzureCredential` to get access to workspace.
#
# `DefaultAzureCredential` should be capable of handling most Azure SDK authentication scenarios.
#
# Reference for more available credentials if it does not work for you: [configure credential example](../../configuration.ipynb), [azure-identity reference doc](https://docs.microsoft.com/en-us/python/api/azure-identity/azure.identity?view=azure-python).

# %%
try:
    credential = DefaultAzureCredential()
    # Check if given credential can get token successfully.
    credential.get_token("https://management.azure.com/.default")
except Exception as ex:
    # Fall back to InteractiveBrowserCredential in case DefaultAzureCredential not work
    credential = InteractiveBrowserCredential()

# %%
print(credential)
# Out:
# <azure.identity._credentials.default.DefaultAzureCredential object at 0x0000021BD013CE20>

# %% [markdown]
# ## 1.3 Get a handle to the workspace
#
# We use config file to connect to a workspace. The Azure ML workspace should be configured with computer cluster. [Check this notebook for configure a workspace](../../configuration.ipynb)

# %%
# Get a handle to workspace
from tokenize import group


#ml_client = MLClient.from_config(credential=credential)
ml_client = MLClient(credential = credential,
    subscription_id="b746917e-ceb7-4ae0-81e6-3ccd893cb0de",
    resource_group_name="dpv2",
    workspace_name="dpv2-wks")


# Retrieve an already attached Azure Machine Learning Compute.
cpu_compute_target = "cpu-cluster"
print(ml_client.compute.get(cpu_compute_target))
#gpu_compute_target = "gpu-cluster"
#print(ml_client.compute.get(gpu_compute_target))
# Out:
# AmlCompute({'type': 'amlcompute', 'created_on': None, 'provisioning_state': 'Succeeded', 'provisioning_errors': None, 'name': 'cpu-cluster', 'description': None, 'tags': {}, 'properties': {}, 'id': '/subscriptions/b746917e-ceb7-4ae0-81e6-3ccd893cb0de/resourceGroups/dpv2/providers/Microsoft.MachineLearningServices/workspaces/dpv2-wks/computes/cpu-cluster', 'Resource__source_path': None, 'base_path': 'd:\\code\\dpv2demo\\notebook\\2e_image_classification_keras_minist_convnet', 'creation_context': None, 'serialize': <msrest.serialization.Serializer object at 0x0000021BD0A61F90>, 'resource_id': None, 'location': 'eastus', 'size': 'STANDARD_DS3_V2', 'min_instances': 0, 'max_instances': 2, 'idle_time_before_scale_down': 120.0, 'identity': None, 'ssh_public_access_enabled': True, 'ssh_settings': None, 'network_settings': None, 'tier': 'dedicated'})

# %% [markdown]
# ## 1.4 Prepare Job Input
# By defining `Input`, you create a reference to the data source location. The data remains in its existing location, so no extra storage cost is incurred.

# %%
from azure.ai.ml import Input

fashion_ds = Input(
    path="wasbs://demo@data4mldemo6150520719.blob.core.windows.net/mnist-fashion/"
)

# %%
fashion_ds
# Out:
# {'type': 'uri_folder', 'path': 'wasbs://demo@data4mldemo6150520719.blob.core.windows.net/mnist-fashion/'}

# %% [markdown]
# # 2. Define and load command component
# In this section, we will define and load component to build pipeline in two ways:
# 1. Using python function
# 1. Using yaml

# %% [markdown]
# ## 2.1 Load components defined with python function
# We define `Prep Data` component and `Train Image Classification Keras` component using @command_component respectively in [./prep/prep_component.py](./prep/prep_component.py) and [./train/train_component.py](./train/train_component.py).
#
# Use following code to import component.

# %%
# %load_ext autoreload
# %autoreload 2

# load component function from component python file
from prep.prep_component import prepare_data_component
from train.train_component import keras_train_component

# print hint of components
help(prepare_data_component)
help(keras_train_component)
# Out:
# [autoreload of azure.ai.ml._ml_exceptions failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_ml_exceptions.py", line 14, in <module>
#     from azure.ai.ml.constants._common import (
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._scope_dependent_operations failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_scope_dependent_operations.py", line 11, in <module>
#     from azure.ai.ml._ml_exceptions import ErrorCategory, ErrorTarget, ValidationErrorType, ValidationException
# ImportError: cannot import name 'ValidationErrorType' from 'azure.ai.ml._ml_exceptions' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_ml_exceptions.py)
# ]
# [autoreload of azure.ai.ml._utils.utils failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_utils\utils.py", line 30, in <module>
#     from azure.ai.ml._ml_exceptions import ErrorCategory, ErrorTarget, ValidationErrorType, ValidationException
# ImportError: cannot import name 'ValidationErrorType' from 'azure.ai.ml._ml_exceptions' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_ml_exceptions.py)
# ]
# [autoreload of azure.ai.ml.entities._assets.asset failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\entities\_assets\asset.py", line 10, in <module>
#     from azure.ai.ml._ml_exceptions import (
# ImportError: cannot import name 'ValidationErrorType' from 'azure.ai.ml._ml_exceptions' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_ml_exceptions.py)
# ]
# [autoreload of azure.ai.ml._schema.core.schema failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\core\schema.py", line 17, in <module>
#     from azure.ai.ml.constants._common import BASE_PATH_CONTEXT_KEY, FILE_PREFIX, PARAMS_OVERRIDE_KEY
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._utils._arm_id_utils failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_utils\_arm_id_utils.py", line 9, in <module>
#     from azure.ai.ml._ml_exceptions import ErrorCategory, ErrorTarget, ValidationErrorType, ValidationException
# ImportError: cannot import name 'ValidationErrorType' from 'azure.ai.ml._ml_exceptions' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_ml_exceptions.py)
# ]
# [autoreload of azure.ai.ml._utils._experimental failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_utils\_experimental.py", line 10, in <module>
#     from azure.ai.ml.constants._common import (
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.core.fields failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\core\fields.py", line 31, in <module>
#     from azure.ai.ml.constants._common import (
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.job.base_job failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\job\base_job.py", line 11, in <module>
#     from azure.ai.ml.constants._common import AzureMLResourceType
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.job.input_output_entry failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\job\input_output_entry.py", line 13, in <module>
#     from azure.ai.ml.constants._common import LOCAL_PATH, AssetTypes, AzureMLResourceType, InputOutputModes
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.assets.environment failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\assets\environment.py", line 14, in <module>
#     from azure.ai.ml.constants._common import (
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.job.parameterized_command failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\job\parameterized_command.py", line 7, in <module>
#     from azure.ai.ml._schema.core.fields import CodeField, NestedField
# ImportError: cannot import name 'CodeField' from 'azure.ai.ml._schema.core.fields' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\core\fields.py)
# ]
# [autoreload of azure.ai.ml._schema.component.input_output failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\component\input_output.py", line 9, in <module>
#     from azure.ai.ml._schema.core.fields import DumpableEnumField, UnionField
# ImportError: cannot import name 'DumpableEnumField' from 'azure.ai.ml._schema.core.fields' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\core\fields.py)
# ]
# [autoreload of azure.ai.ml._schema.component.component failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\component\component.py", line 9, in <module>
#     from azure.ai.ml.constants._common import BASE_PATH_CONTEXT_KEY, AzureMLResourceType
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.component.command_component failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\component\command_component.py", line 14, in <module>
#     from azure.ai.ml._schema.component.input_output import OutputPortSchema, PrimitiveOutputSchema
# ImportError: cannot import name 'PrimitiveOutputSchema' from 'azure.ai.ml._schema.component.input_output' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\component\input_output.py)
# ]
# [autoreload of azure.ai.ml._schema.component.parallel_task failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\component\parallel_task.py", line 9, in <module>
#     from azure.ai.ml._schema.core.fields import ArmVersionedStr, CodeField, NestedField, StringTransformedEnum, UnionField
# ImportError: cannot import name 'CodeField' from 'azure.ai.ml._schema.core.fields' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\core\fields.py)
# ]
# [autoreload of azure.ai.ml._schema.component.parallel_component failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\component\parallel_component.py", line 18, in <module>
#     from azure.ai.ml.constants._common import BASE_PATH_CONTEXT_KEY, LoggingLevel
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.component failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\component\__init__.py", line 9, in <module>
#     from .import_component import AnonymousImportComponentSchema, ImportComponentFileRefField, ImportComponentSchema
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\component\import_component.py", line 14, in <module>
#     from azure.ai.ml.constants._common import BASE_PATH_CONTEXT_KEY
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.job.parameterized_parallel failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\job\parameterized_parallel.py", line 12, in <module>
#     from azure.ai.ml.constants._common import LoggingLevel
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.job failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\job\__init__.py", line 11, in <module>
#     from .import_job import ImportJobSchema
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\job\import_job.py", line 10, in <module>
#     from azure.ai.ml.constants import ImportSourceType, JobType
# ImportError: cannot import name 'ImportSourceType' from 'azure.ai.ml.constants' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\constants.py)
# ]
# [autoreload of azure.ai.ml._schema._sweep.search_space.normal failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\_sweep\search_space\normal.py", line 12, in <module>
#     from azure.ai.ml.constants._common import TYPE
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema._sweep.search_space.randint failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\_sweep\search_space\randint.py", line 11, in <module>
#     from azure.ai.ml.constants._job.sweep import SearchSpace
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._job'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema._sweep.search_space.uniform failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\_sweep\search_space\uniform.py", line 12, in <module>
#     from azure.ai.ml.constants._common import TYPE
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema._sweep.search_space.choice failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\_sweep\search_space\choice.py", line 20, in <module>
#     from azure.ai.ml.constants._job.sweep import SearchSpace
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._job'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.assets.artifact failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\assets\artifact.py", line 11, in <module>
#     from azure.ai.ml.constants._common import BASE_PATH_CONTEXT_KEY
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.assets.code_asset failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\assets\code_asset.py", line 12, in <module>
#     from azure.ai.ml.constants._common import BASE_PATH_CONTEXT_KEY, AzureMLResourceType
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.assets.data failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\assets\data.py", line 9, in <module>
#     from azure.ai.ml.constants._common import AssetTypes
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.assets.model failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\assets\model.py", line 14, in <module>
#     from azure.ai.ml.constants._common import BASE_PATH_CONTEXT_KEY, AssetTypes, AzureMLResourceType
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\__init__.py", line 12, in <module>
#     from .assets.workspace_model_reference import WorkspaceModelReferenceSchema
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\assets\workspace_model_reference.py", line 11, in <module>
#     from azure.ai.ml.constants._common import BASE_PATH_CONTEXT_KEY
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._azure_environments failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_azure_environments.py", line 12, in <module>
#     from azure.ai.ml.constants._common import AZUREML_CLOUD_ENV_NAME
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml.entities._datastore.credentials failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 480, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 329, in update_class
#     if update_generic(old_obj, new_obj):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 289, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of azure.ai.ml._schema._deployment.deployment failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\_deployment\deployment.py", line 12, in <module>
#     from azure.ai.ml.constants._common import AzureMLResourceType
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema._deployment.batch.batch_deployment failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\_deployment\batch\batch_deployment.py", line 16, in <module>
#     from azure.ai.ml.constants._common import BASE_PATH_CONTEXT_KEY
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema._deployment.online.online_deployment failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\_deployment\online\online_deployment.py", line 17, in <module>
#     from azure.ai.ml.constants._common import BASE_PATH_CONTEXT_KEY, PublicNetworkAccess
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema._endpoint.batch.batch_endpoint failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\_endpoint\batch\batch_endpoint.py", line 15, in <module>
#     from azure.ai.ml.constants._common import BASE_PATH_CONTEXT_KEY
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema._endpoint.online.online_endpoint failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\_endpoint\online\online_endpoint.py", line 14, in <module>
#     from azure.ai.ml.constants._common import BASE_PATH_CONTEXT_KEY, AzureMLResourceType, PublicNetworkAccess
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.compute.aml_compute failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\compute\aml_compute.py", line 11, in <module>
#     from azure.ai.ml.constants._compute import ComputeTier, ComputeType
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._compute'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.compute.compute_instance failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\compute\compute_instance.py", line 10, in <module>
#     from azure.ai.ml.constants._compute import ComputeType
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._compute'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.compute.virtual_machine_compute failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\compute\virtual_machine_compute.py", line 11, in <module>
#     from azure.ai.ml.constants._compute import ComputeType
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._compute'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._schema.pipeline.pipeline_job_io failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\pipeline\pipeline_job_io.py", line 12, in <module>
#     from azure.ai.ml.constants._component import ComponentJobConstants
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._component'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml.entities._job.pipeline._exceptions failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 480, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 329, in update_class
#     if update_generic(old_obj, new_obj):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 289, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of azure.ai.ml.entities._inputs_outputs failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\entities\_inputs_outputs.py", line 68, in <module>
#     from azure.ai.ml._ml_exceptions import ErrorCategory, ErrorTarget, ValidationErrorType, ValidationException
# ImportError: cannot import name 'ValidationErrorType' from 'azure.ai.ml._ml_exceptions' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_ml_exceptions.py)
# ]
# [autoreload of azure.ai.ml._schema.pipeline.component_job failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\pipeline\component_job.py", line 13, in <module>
#     from azure.ai.ml._schema.component import (
# ImportError: cannot import name 'AnonymousImportComponentSchema' from 'azure.ai.ml._schema.component' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\component\__init__.py)
# ]
# [autoreload of azure.ai.ml._schema.pipeline.settings failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_schema\pipeline\settings.py", line 11, in <module>
# ...
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\operations\_online_endpoint_operations.py", line 13, in <module>
#     from azure.ai.ml._ml_exceptions import (
# ImportError: cannot import name 'ValidationErrorType' from 'azure.ai.ml._ml_exceptions' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_ml_exceptions.py)
# ]
# [autoreload of azure.ai.ml._arm_deployments.arm_helper failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_arm_deployments\arm_helper.py", line 10, in <module>
#     from azure.ai.ml.constants._common import ArmConstants, AzureMLResourceType
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._arm_deployments.arm_deployment_executor failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_arm_deployments\arm_deployment_executor.py", line 24, in <module>
#     from azure.ai.ml.constants._common import (
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._utils._workspace_utils failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_utils\_workspace_utils.py", line 11, in <module>
#     from azure.ai.ml.constants._common import ArmConstants
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml.operations._workspace_operations failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\operations\_workspace_operations.py", line 32, in <module>
#     from azure.ai.ml.constants._common import ArmConstants, LROConfigurations, WorkspaceResourceConstants
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml.operations._schedule_operations failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\operations\_schedule_operations.py", line 21, in <module>
#     from ..constants._common import AzureMLResourceType, LROConfigurations
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml._ml_client failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_ml_client.py", line 38, in <module>
#     from azure.ai.ml.constants._common import REGISTRY_DISCOVERY_BASE_URI, AzureMLResourceType
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml.entities._builders.command_func failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\entities\_builders\command_func.py", line 10, in <module>
#     from azure.ai.ml._ml_exceptions import ErrorTarget, ValidationErrorType, ValidationException
# ImportError: cannot import name 'ValidationErrorType' from 'azure.ai.ml._ml_exceptions' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\_ml_exceptions.py)
# ]
# [autoreload of azure.ai.ml failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\__init__.py", line 16, in <module>
#     from .entities._builders.spark_func import spark
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\entities\_builders\spark_func.py", line 11, in <module>
#     from azure.ai.ml.constants._common import AssetTypes
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._common'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml.dsl._pipeline_component_builder failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\dsl\_pipeline_component_builder.py", line 19, in <module>
#     from azure.ai.ml.constants._component import ComponentSource
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._component'; 'azure.ai.ml.constants' is not a package
# ]
# [autoreload of azure.ai.ml.dsl._pipeline_decorator failed: Traceback (most recent call last):
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\IPython\extensions\autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\dsl\_pipeline_decorator.py", line 15, in <module>
#     from azure.ai.ml.entities._inputs_outputs import Input, is_parameter_group
# ImportError: cannot import name 'is_parameter_group' from 'azure.ai.ml.entities._inputs_outputs' (c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\azure\ai\ml\entities\_inputs_outputs.py)
# ]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\mldesigner\_dependent_component_executor.py:74, in DependentComponentExecutor.component(self)
#      72 try:
#      73     # package version: azure.ai.ml > 0.1.0b4
# ---> 74     from azure.ai.ml.constants._component import NodeType
#      75     from azure.ai.ml.entities._component.component_factory import component_factory
#
# ModuleNotFoundError: No module named 'azure.ai.ml.constants._component'; 'azure.ai.ml.constants' is not a package
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# d:\code\dpv2demo\notebook\2e_image_classification_keras_minist_convnet\image_classification_keras_minist_convnet.ipynb Cell 14 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/d%3A/code/dpv2demo/notebook/2e_image_classification_keras_minist_convnet/image_classification_keras_minist_convnet.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> get_ipython().run_line_magic('autoreload', '2')
#       <a href='vscode-notebook-cell:/d%3A/code/dpv2demo/notebook/2e_image_classification_keras_minist_convnet/image_classification_keras_minist_convnet.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> # load component function from component python file
# ----> <a href='vscode-notebook-cell:/d%3A/code/dpv2demo/notebook/2e_image_classification_keras_minist_convnet/image_classification_keras_minist_convnet.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> from prep.prep_component import prepare_data_component
#       <a href='vscode-notebook-cell:/d%3A/code/dpv2demo/notebook/2e_image_classification_keras_minist_convnet/image_classification_keras_minist_convnet.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> from train.train_component import keras_train_component
#       <a href='vscode-notebook-cell:/d%3A/code/dpv2demo/notebook/2e_image_classification_keras_minist_convnet/image_classification_keras_minist_convnet.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a> # print hint of components
#
# File d:\code\dpv2demo\notebook\2e_image_classification_keras_minist_convnet\prep\prep_component.py:17, in <module>
#       3 from pathlib import Path
#       4 from mldesigner import command_component, Input, Output
#       7 @command_component(
#       8     name="prep_data",
#       9     version="1",
#      10     display_name="Prep Data",
#      11     description="Convert data to CSV file, and split to training and test data",
#      12     environment=dict(
#      13         conda_file=Path(__file__).parent / "conda.yaml",
#      14         image="mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04",
#      15     ),
#      16 )
# ---> 17 def prepare_data_component(
#      18     input_data: Input(type="uri_folder"),
#      19     training_data: Output(type="uri_folder"),
#      20     test_data: Output(type="uri_folder"),
#      21 ):
#      22     convert(
#      23         os.path.join(input_data, "train-images-idx3-ubyte"),
#      24         os.path.join(input_data, "train-labels-idx1-ubyte"),
#      25         os.path.join(training_data, "mnist_train.csv"),
#      26         60000,
#      27     )
#      28     convert(
#      29         os.path.join(input_data, "t10k-images-idx3-ubyte"),
#      30         os.path.join(input_data, "t10k-labels-idx1-ubyte"),
#      31         os.path.join(test_data, "mnist_test.csv"),
#      32         10000,
#      33     )
#
# File c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\mldesigner\_component.py:192, in command_component.<locals>.component_func_decorator(func)
#     190 wrapper._executor = executor
#     191 if EXECUTOR_CLASS != ComponentExecutor:
# --> 192     wrapper.component = executor.component
#     193 return wrapper
#
# File c:\Users\tangm\anaconda3\envs\dpv2\lib\site-packages\mldesigner\_dependent_component_executor.py:87, in DependentComponentExecutor.component(self)
#      83     return component
#      84 except ImportError:
#      85     # pylint: disable=no-member
#      86     # package version: azure.ai.ml <= 0.1.0b4
# ---> 87     component = CommandComponent._load_from_dict(
#      88         {**entity_args, **io_properties},
#      89         context={BASE_PATH_CONTEXT_KEY: Path("./")},
#      90         _source=ComponentSource.MLDESIGNER,
#      91     )
#      92     return component
#      93 except Exception as e:
#
# AttributeError: type object 'CommandComponent' has no attribute '_load_from_dict'

# %% [markdown]
# (Optional) Python import will have cache if the code does not change. However, if you change the conda.yaml file, you will need to force re-import.

# %%
# import importlib, prep.prep_component, train.train_component
# importlib.reload(prep.prep_component)
# importlib.reload(train.train_component)
# from prep.prep_component import prepare_data_component
# from train.train_component import keras_train_component

# %% [markdown]
# ## 2.2 Load component defined with yaml
# We define `Score Image Classification Keras` in [yaml](./score/score.yaml).
#
# Use following code to load component from yaml.

# %%
# load component function from yaml
keras_score_component = load_component(path="./score/score.yaml")

# %% [markdown]
# # 3. Build pipeline
#
# We define a pipeline containing 3 nodes:
# - `prepare_data_node` will load the image and labels from Fashion MNIST dataset into mnist_train.csv and mnist_test.csv.
# - `train_node` will train a CNN model with Keras using training data.
# - `score_node` will score the model using test data.

# %%
# define a pipeline containing 3 nodes: Prepare data node, train node, and score node
@pipeline(
    default_compute=cpu_compute_target,
)
def image_classification_keras_minist_convnet(pipeline_input_data):
    """E2E image classification pipeline with keras using python sdk."""
    prepare_data_node = prepare_data_component(input_data=pipeline_input_data)

    train_node = keras_train_component(
        input_data=prepare_data_node.outputs.training_data
    )
    train_node.compute = gpu_compute_target

    score_node = keras_score_component(
        input_data=prepare_data_node.outputs.test_data,
        input_model=train_node.outputs.output_model,
    )


# create a pipeline
pipeline_job = image_classification_keras_minist_convnet(pipeline_input_data=fashion_ds)

# %%
print(pipeline_job)

# %% [markdown]
# # 4. Submit pipeline job

# %%
pipeline_job = ml_client.jobs.create_or_update(
    pipeline_job, experiment_name="pipeline_samples"
)
pipeline_job

# %%
# wait until the job completes
ml_client.jobs.stream(pipeline_job.name)

# %% [markdown]
# # 5. (Optional) Register your component to workspace
#
# If you want to share and reuse your component within workspace, you can also register it to a machine learning workspace.
#
# The following sample code shows how to register a component to your workspace and get a registered component from your workspace.

# %%
try:
    # try get back the component
    prep = ml_client.components.get(name="prep_data", version="1")
except:
    # if not exists, register component using following code
    prep = ml_client.components.create_or_update(prepare_data_component)

# list all components registered in workspace
for c in ml_client.components.list():
    print(c)

# %% [markdown]
# # Next Steps
# You can see further examples of running a pipeline job [here](../)
